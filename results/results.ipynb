# %%
# !nim c ../src/test.nim
# !../src/test

import json
import numpy as np
import matplotlib.pyplot as plt

with open('testOneResults.json') as f:
    results = np.array(json.load(f)) * 63

plt.plot(np.arange(1, 101) / 2, results[0])
plt.plot(np.arange(1, 101) / 2, results[1])
plt.xlabel('time (ms)')
plt.ylabel('potential (mV)')
plt.show()
# Out:
# Hint: used config file '/home/jack/.choosenim/toolchains/nim-1.6.12/config/nim.cfg' [Conf]
# Hint: used config file '/home/jack/.choosenim/toolchains/nim-1.6.12/config/config.nims' [Conf]
# ......................................................................................................
# Hint:  [Link]
# Hint: gc: refc; opt: none (DEBUG BUILD, `-d:release` generates faster code)
# 57874 lines; 0.724s; 75.266MiB peakmem; proj: /home/jack/Documents/snn/src/test.nim; out: /home/jack/Documents/snn/src/test [SuccessX]
